# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %% [markdown]
# ## Parse the completed trials

# %%
import os
import datetime
import psycopg2
import pandas as pd

from typing import List
from sqlalchemy import create_engine, text

# %%
username = os.environ["USERNAME"]
password = os.environ["PASSWORD"]
hostname = os.environ["HOSTNAME"]
database = "aact"
port = os.environ["PORT"]

db_credentials = f"postgresql://{username}:{password}@{hostname}:{port}/{database}"
engine = create_engine(db_credentials)
db_connections = engine.connect()

# %%
sql_query = text(
    f"""
SELECT
    studies.nct_id,
    MAX(studies.brief_title) AS brief_title,
    MAX(studies.official_title) AS official_title,
    MAX(studies.overall_status) AS overall_status,
    STRING_AGG(DISTINCT baseline_measurements.description, ' ') AS baseline_measurements,
    STRING_AGG(DISTINCT brief_summaries.description, ' ') AS brief_summaries,
    STRING_AGG(DISTINCT detailed_descriptions.description, ' ') AS detailed_descriptions,
    MAX(eligibilities.criteria) AS criteria, 
    MAX(eligibilities.gender) AS gender, 
    MAX(eligibilities.minimum_age) AS minimum_age, 
    MAX(eligibilities.maximum_age) AS maximum_age, 
    MAX(facilities.name) AS facilities, 
    MAX(facilities.city) AS city, 
    MAX(facilities.state) AS state, 
    MAX(facilities.zip) AS zip, 
    MAX(facilities.country) AS country, 
    MAX(participant_flows.recruitment_details) AS recruitment_details, 
    MAX(participant_flows.pre_assignment_details) AS pre_assignment_details, 
    MAX(studies.study_type) AS study_type
FROM 
    ctgov.studies
INNER JOIN ctgov.baseline_measurements ON baseline_measurements.nct_id = studies.nct_id 
INNER JOIN ctgov.brief_summaries ON brief_summaries.nct_id = studies.nct_id 
INNER JOIN ctgov.detailed_descriptions ON detailed_descriptions.nct_id = studies.nct_id 
INNER JOIN ctgov.eligibilities ON eligibilities.nct_id = studies.nct_id 
INNER JOIN ctgov.facilities ON facilities.nct_id = studies.nct_id 
INNER JOIN ctgov.participant_flows ON participant_flows.nct_id = studies.nct_id 
WHERE
    studies.overall_status = 'Completed'
GROUP BY studies.nct_id;
"""
)

# Execute the SQL query and create a pandas DataFrame from the result
df = pd.read_sql_query(
    sql_query,
    engine,
    params={}  # type: ignore
)
df
# Out:
#             nct_id                                        brief_title  \
# 0      NCT00000143  Studies of Ocular Complications of AIDS (SOCA)...
# 1      NCT00000378  Antidepressant Treatment of Melancholia in Lat...
# 2      NCT00000620  Action to Control Cardiovascular Risk in Diabe...
# 3      NCT00001213  Cysteamine Eye Drops to Treat Corneal Crystals...
# 4      NCT00001259  A Treatment Study for Premenstrual Syndrome (PMS)
# ...            ...                                                ...
# 28618  NCT05451225  Survey of Correction Officers Before and After...
# 28619  NCT05489146        t-RNS After Hand Recovery in Chronic Stroke
# 28620  NCT05502081  Clinical Study to Compare Efficacy and Safety ...
# 28621  NCT05594173          Chewing and Oral Processing of Solid Food
# 28622  NCT05736861  ACTIV-6: COVID-19 Study of Repurposed Medicati...
#
#                                           official_title overall_status  \
# 0      Studies of Ocular Complications of AIDS (SOCA)...      Completed
# 1      Antidepressant Treatment of Melancholia in Lat...      Completed
# 2      Action to Control Cardiovascular Risk in Diabe...      Completed
# 3      Trial of Topical Cysteamine in the Treatment o...      Completed
# 4      The Treatment of Menstrually-Related Mood Diso...      Completed
# ...                                                  ...            ...
# 28618  Reducing Duration of Untreated Psychosis Throu...      Completed
# 28619  Combining Transcranial Random Noise Stimulatio...      Completed
# 28620  Clinical Study to Evaluate the Possible Effica...      Completed
# 28621  Chewing and Oral Processing of Solid Food in H...      Completed
# 28622  ACTIV-6: COVID-19 Outpatient Randomized Trial ...      Completed
#
#                                    baseline_measurements  \
# 0                                                   None
# 1                                                   None
# 2                                                   None
# 3      Although 328 participants were initially enrol...
# 4                                                   None
# ...                                                  ...
# 28618                                               None
# 28619  Fugl Meyer Upper Extremity Assessment (FMUE) m...
# 28620  0. Uninfected\n\nAmbulatory mild disease\n\nAs...
# 28621                                               None
# 28622                                               None
#
#                                          brief_summaries  \
# 0      To compare the newest CMV retinitis drug, cido...
# 1      The purpose of this study is to compare the sa...
# 2      The purpose of this study is to prevent major ...
# 3      Cystinosis is an inherited disease that result...
# 4      This study examines the effects of estrogen an...
# ...                                                  ...
# 28618  The investigators will implement a multifacete...
# 28619  Upper extremity (UE) paresis or weakness is on...
# 28620  Introduction:\n\nCorona Virus induced disease ...
# 28621  Food texture modification is commonly used as ...
# 28622  The purpose of this study is to evaluate the e...
#
#                                    detailed_descriptions  \
# 0      Cytomegalovirus (CMV) is among the most freque...
# 1      To compare the efficacy and safety of a select...
# 2      BACKGROUND:\n\nCurrently, about 17 million Ame...
# 3      Protocol 86-EI-0062 began as a randomized, dou...
# 4      This protocol is designed to accompany Clinica...
# ...                                                  ...
# 28618  Because Correction Officers in the three jails...
# 28619  The primary purpose of this study was to inves...
# 28620  I. INTRODUCTION\n\n1.1. COVID-19 overview and ...
# 28621  Aim: To explore chewing and oral processing be...
# 28622  Severe acute respiratory syndrome coronavirus ...
#
#                                                 criteria  gender minimum_age  \
# 0      Inclusion criteria:\n\nAge 13 years or older\n...     All    13 Years
# 1      Inclusion Criteria:\n\n-\n\nPatients must have...     All    60 Years
# 2      Inclusion Criteria:\n\nDiagnosed with type 2 d...     All    40 Years
# 3      INCLUSION CRITERIA:\n\nPatients must have a do...     All     2 Years
# 4      INCLUSION CRITERIA:\n\nThe subjects of this st...  Female    18 Years
# ...                                                  ...     ...         ...
# 28618  Inclusion Criteria:\n\nCorrection Officers;\no...     All    21 Years
# 28619  Inclusion Criteria:\n\nAge 18 or older\nEpisod...     All    18 Years
# 28620  Inclusion Criteria:\n\nage more than 12 years ...     All    12 Years
# 28621  Inclusion Criteria:\n\nHealthy adults under ag...     All    18 Years
# 28622  Inclusion Criteria:\n\nCompleted Informed Cons...     All    30 Years
#
#       maximum_age                                         facilities  \
# 0             N/A            University of South Florida, MDC Box 21
# 1        95 Years                               1051 Riverside Drive
# 2        79 Years                             Wake Forest University
# 3             N/A  National Institutes of Health Clinical Center,...
# 4        45 Years  National Institutes of Health Clinical Center,...
# ...           ...                                                ...
# 28618         N/A                                Columbia University
# 28619    80 Years         Neuromotor Recovery and Rehabilitation Lab
# 28620         N/A                                     El-gomhoria St
# 28621    60 Years  Toronto Rehabilitation Institute - University ...
# 28622         N/A                       Well Pharma Medical Research
#
#                 city         state      zip        country  \
# 0              Tampa         Texas    94143  United States
# 1           New York      New York    10032  United States
# 2      Winston-Salem    Washington    98195  United States
# 3           Bethesda      Maryland    20892  United States
# 4           Bethesda      Maryland    20892  United States
# ...              ...           ...      ...            ...
# 28618       New York      New York    10027  United States
# 28619     Pittsburgh  Pennsylvania    15260  United States
# 28620       Mansoura    El-dkhalia      050          Egypt
# 28621        Toronto       Ontario  M5G 2A2         Canada
# 28622        Yonkers      Virginia    94304  United States
#
#                                      recruitment_details  \
# 0                                              June 1997
# 1                                                   None
# 2      All participants had established type 2 diabet...
# 3                                                   None
# 4      One participant signed consent but withdrew pr...
# ...                                                  ...
# 28618  Recruitment of the study sample took place in ...
# 28619                                               None
# 28620  from 1/11/2021 to 29/5/2022 at isolation hospi...
# 28621                                               None
# 28622                                               None
#
#                                   pre_assignment_details      study_type
# 0                                                   None  Interventional
# 1                                                   None  Interventional
# 2      Eligible participants provided evidence of abi...  Interventional
# 3                                                   None  Interventional
# 4      8 of 46 participants who completed Study 2, Ph...  Interventional
# ...                                                  ...             ...
# 28618  Correction officers (COs) were recruited at ea...  Interventional
# 28619                                               None  Interventional
# 28620  assignment is applied after admission of parti...  Interventional
# 28621                                               None   Observational
# 28622                                               None  Interventional
#
# [28623 rows x 19 columns]

# %%
len(df)
# Out:
# 28623

# %%
df.set_index(df['nct_id'], inplace=True)
df.drop(columns=['nct_id'], inplace=True)

# %%
output = "ctgov"
timestamp = datetime.datetime.now().strftime("%Y%m%d")
file_name = f"{output}_{timestamp}.csv"
# Write the data to output filename
df.to_csv(file_name)

# %% [markdown]
# ## Counting with tiktoken

# %%
import tiktoken
model = "cl100k_base"
encoder = tiktoken.get_encoding(model)

df = pd.read_csv("ctgov_20230613.csv", index_col="nct_id")
df
# Out:
#                                                    brief_title  \
# nct_id
# NCT00000143  Studies of Ocular Complications of AIDS (SOCA)...
# NCT00000378  Antidepressant Treatment of Melancholia in Lat...
# NCT00000620  Action to Control Cardiovascular Risk in Diabe...
# NCT00001213  Cysteamine Eye Drops to Treat Corneal Crystals...
# NCT00001259  A Treatment Study for Premenstrual Syndrome (PMS)
# ...                                                        ...
# NCT05451225  Survey of Correction Officers Before and After...
# NCT05489146        t-RNS After Hand Recovery in Chronic Stroke
# NCT05502081  Clinical Study to Compare Efficacy and Safety ...
# NCT05594173          Chewing and Oral Processing of Solid Food
# NCT05736861  ACTIV-6: COVID-19 Study of Repurposed Medicati...
#
#                                                 official_title overall_status  \
# nct_id
# NCT00000143  Studies of Ocular Complications of AIDS (SOCA)...      Completed
# NCT00000378  Antidepressant Treatment of Melancholia in Lat...      Completed
# NCT00000620  Action to Control Cardiovascular Risk in Diabe...      Completed
# NCT00001213  Trial of Topical Cysteamine in the Treatment o...      Completed
# NCT00001259  The Treatment of Menstrually-Related Mood Diso...      Completed
# ...                                                        ...            ...
# NCT05451225  Reducing Duration of Untreated Psychosis Throu...      Completed
# NCT05489146  Combining Transcranial Random Noise Stimulatio...      Completed
# NCT05502081  Clinical Study to Evaluate the Possible Effica...      Completed
# NCT05594173  Chewing and Oral Processing of Solid Food in H...      Completed
# NCT05736861  ACTIV-6: COVID-19 Outpatient Randomized Trial ...      Completed
#
#                                          baseline_measurements  \
# nct_id
# NCT00000143                                                NaN
# NCT00000378                                                NaN
# NCT00000620                                                NaN
# NCT00001213  Although 328 participants were initially enrol...
# NCT00001259                                                NaN
# ...                                                        ...
# NCT05451225                                                NaN
# NCT05489146  Fugl Meyer Upper Extremity Assessment (FMUE) m...
# NCT05502081  0. Uninfected\n\nAmbulatory mild disease\n\nAs...
# NCT05594173                                                NaN
# NCT05736861                                                NaN
#
#                                                brief_summaries  \
# nct_id
# NCT00000143  To compare the newest CMV retinitis drug, cido...
# NCT00000378  The purpose of this study is to compare the sa...
# NCT00000620  The purpose of this study is to prevent major ...
# NCT00001213  Cystinosis is an inherited disease that result...
# NCT00001259  This study examines the effects of estrogen an...
# ...                                                        ...
# NCT05451225  The investigators will implement a multifacete...
# NCT05489146  Upper extremity (UE) paresis or weakness is on...
# NCT05502081  Introduction:\n\nCorona Virus induced disease ...
# NCT05594173  Food texture modification is commonly used as ...
# NCT05736861  The purpose of this study is to evaluate the e...
#
#                                          detailed_descriptions  \
# nct_id
# NCT00000143  Cytomegalovirus (CMV) is among the most freque...
# NCT00000378  To compare the efficacy and safety of a select...
# NCT00000620  BACKGROUND:\n\nCurrently, about 17 million Ame...
# NCT00001213  Protocol 86-EI-0062 began as a randomized, dou...
# NCT00001259  This protocol is designed to accompany Clinica...
# ...                                                        ...
# NCT05451225  Because Correction Officers in the three jails...
# NCT05489146  The primary purpose of this study was to inves...
# NCT05502081  I. INTRODUCTION\n\n1.1. COVID-19 overview and ...
# NCT05594173  Aim: To explore chewing and oral processing be...
# NCT05736861  Severe acute respiratory syndrome coronavirus ...
#
#                                                       criteria  gender  \
# nct_id
# NCT00000143  Inclusion criteria:\n\nAge 13 years or older\n...     All
# NCT00000378  Inclusion Criteria:\n\n-\n\nPatients must have...     All
# NCT00000620  Inclusion Criteria:\n\nDiagnosed with type 2 d...     All
# NCT00001213  INCLUSION CRITERIA:\n\nPatients must have a do...     All
# NCT00001259  INCLUSION CRITERIA:\n\nThe subjects of this st...  Female
# ...                                                        ...     ...
# NCT05451225  Inclusion Criteria:\n\nCorrection Officers;\no...     All
# NCT05489146  Inclusion Criteria:\n\nAge 18 or older\nEpisod...     All
# NCT05502081  Inclusion Criteria:\n\nage more than 12 years ...     All
# NCT05594173  Inclusion Criteria:\n\nHealthy adults under ag...     All
# NCT05736861  Inclusion Criteria:\n\nCompleted Informed Cons...     All
#
#             minimum_age maximum_age  \
# nct_id
# NCT00000143    13 Years         NaN
# NCT00000378    60 Years    95 Years
# NCT00000620    40 Years    79 Years
# NCT00001213     2 Years         NaN
# NCT00001259    18 Years    45 Years
# ...                 ...         ...
# NCT05451225    21 Years         NaN
# NCT05489146    18 Years    80 Years
# NCT05502081    12 Years         NaN
# NCT05594173    18 Years    60 Years
# NCT05736861    30 Years         NaN
#
#                                                     facilities           city  \
# nct_id
# NCT00000143            University of South Florida, MDC Box 21          Tampa
# NCT00000378                               1051 Riverside Drive       New York
# NCT00000620                             Wake Forest University  Winston-Salem
# NCT00001213  National Institutes of Health Clinical Center,...       Bethesda
# NCT00001259  National Institutes of Health Clinical Center,...       Bethesda
# ...                                                        ...            ...
# NCT05451225                                Columbia University       New York
# NCT05489146         Neuromotor Recovery and Rehabilitation Lab     Pittsburgh
# NCT05502081                                     El-gomhoria St       Mansoura
# NCT05594173  Toronto Rehabilitation Institute - University ...        Toronto
# NCT05736861                       Well Pharma Medical Research        Yonkers
#
#                     state      zip        country  \
# nct_id
# NCT00000143         Texas    94143  United States
# NCT00000378      New York    10032  United States
# NCT00000620    Washington    98195  United States
# NCT00001213      Maryland    20892  United States
# NCT00001259      Maryland    20892  United States
# ...                   ...      ...            ...
# NCT05451225      New York    10027  United States
# NCT05489146  Pennsylvania    15260  United States
# NCT05502081    El-dkhalia      050          Egypt
# NCT05594173       Ontario  M5G 2A2         Canada
# NCT05736861      Virginia    94304  United States
#
#                                            recruitment_details  \
# nct_id
# NCT00000143                                          June 1997
# NCT00000378                                                NaN
# NCT00000620  All participants had established type 2 diabet...
# NCT00001213                                                NaN
# NCT00001259  One participant signed consent but withdrew pr...
# ...                                                        ...
# NCT05451225  Recruitment of the study sample took place in ...
# NCT05489146                                                NaN
# NCT05502081  from 1/11/2021 to 29/5/2022 at isolation hospi...
# NCT05594173                                                NaN
# NCT05736861                                                NaN
#
#                                         pre_assignment_details      study_type
# nct_id
# NCT00000143                                                NaN  Interventional
# NCT00000378                                                NaN  Interventional
# NCT00000620  Eligible participants provided evidence of abi...  Interventional
# NCT00001213                                                NaN  Interventional
# NCT00001259  8 of 46 participants who completed Study 2, Ph...  Interventional
# ...                                                        ...             ...
# NCT05451225  Correction officers (COs) were recruited at ea...  Interventional
# NCT05489146                                                NaN  Interventional
# NCT05502081  assignment is applied after admission of parti...  Interventional
# NCT05594173                                                NaN   Observational
# NCT05736861                                                NaN  Interventional
#
# [28623 rows x 18 columns]

# %%
df["concat"] = df.apply(lambda x: ' '.join(
    x.astype(str) if x is not None else "None. "), axis=1)
df["tokens"] = df["concat"].apply(lambda x: encoder.encode(x))
df["num_tokens"] = df["tokens"].apply(lambda x: len(x))
total_tokens = df['num_tokens'].sum()
# $0.0004 per 1000 tokens
total_price = total_tokens / 1000 * 0.0004
print(f"Price for {total_tokens} tokens is ${total_price}")
# Out:
# Price for 163015532 tokens is $65.2062128
